# %% [markdown]
# # 第0回：Environment & Dataset Foundation

# %% [markdown]
# 第0回は、環境のテストです。これから扱う深層学習モデルはpytorchやgpuの利用前提(cpuでも動きますが強くないととても時間がかかります)なので、事前に動かせる環境かどうかをテストするコードをおいています。

# %% [markdown]
# ## pytorch test

# %%
# 実行環境のセルフチェック用
import torch
print(f"PyTorch: {torch.__version__}")
print(f"CUDA available: {torch.cuda.is_available()}")
# Out:
# PyTorch: 2.11.0+cu130
# CUDA available: True
